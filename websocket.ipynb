# %%
API_KEY = "PK3YUI7JLFQFSPG25STNLEZNES"
API_SECRET = "HeMC4cxcg8XHvSy34T5Yk8mWZ3xJV4LXRkPiSvYJEPCw"
BASE_URL = "https://paper-api.alpaca.markets"
DATA_URL = "https://data.alpaca.markets/v2"

# %%
stock_client = StockHistoricalDataClient(API_KEY, API_SECRET)
fx_client = ForexHistoricalDataClient(API_KEY, API_SECRET)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stock_client = StockHistoricalDataClient(API_KEY, API_SECRET)
#       2 fx_client = ForexHistoricalDataClient(API_KEY, API_SECRET)
#
# NameError: name 'StockHistoricalDataClient' is not defined
